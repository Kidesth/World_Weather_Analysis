# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
# Import the requests library.
import requests
from citipy import citipy

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 733

# %%
# Import the time module.
import time
# Get today's date in seconds.
today = time.time()
today
# Out:
# 1661143767.5008872

# %%
# %store -r url

# %%
#Starting URL for weather MAP API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
  # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_dc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "current Description": city_weather_dc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavaratti
# Processing Record 2 of Set 1 | cherskiy
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | saint george
# Processing Record 5 of Set 1 | ornskoldsvik
# Processing Record 6 of Set 1 | rikitea
# Processing Record 7 of Set 1 | matata
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 10 of Set 1 | waipawa
# Processing Record 11 of Set 1 | chapais
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | dikson
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | mataura
# Processing Record 17 of Set 1 | castro
# Processing Record 18 of Set 1 | tecoanapa
# Processing Record 19 of Set 1 | shiyan
# Processing Record 20 of Set 1 | hobart
# Processing Record 21 of Set 1 | morehead
# Processing Record 22 of Set 1 | dingle
# Processing Record 23 of Set 1 | grand gaube
# Processing Record 24 of Set 1 | huanren
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | barranca
# Processing Record 27 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 28 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 29 of Set 1 | tuxpan
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | saint-denis
# Processing Record 32 of Set 1 | riyadh
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | buckingham
# Processing Record 35 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 36 of Set 1 | morant bay
# Processing Record 37 of Set 1 | rawson
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | talaya
# Processing Record 40 of Set 1 | verkhnyaya inta
# Processing Record 41 of Set 1 | provideniya
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | marilia
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | hambantota
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | hay river
# Processing Record 48 of Set 1 | port elizabeth
# Processing Record 49 of Set 1 | san patricio
# Processing Record 50 of Set 1 | oistins
# Processing Record 1 of Set 2 | nanortalik
# Processing Record 2 of Set 2 | vaini
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | krasnoselkup
# Processing Record 7 of Set 2 | egvekinot
# Processing Record 8 of Set 2 | hervey bay
# Processing Record 9 of Set 2 | le mars
# Processing Record 10 of Set 2 | cabo san lucas
# Processing Record 11 of Set 2 | kutum
# Processing Record 12 of Set 2 | guerrero negro
# Processing Record 13 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | touros
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | kruisfontein
# Processing Record 18 of Set 2 | port macquarie
# Processing Record 19 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 2 | bubaque
# Processing Record 21 of Set 2 | havre-saint-pierre
# Processing Record 22 of Set 2 | maues
# Processing Record 23 of Set 2 | san cristobal
# Processing Record 24 of Set 2 | bardiyah
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | kapaa
# Processing Record 28 of Set 2 | hofn
# Processing Record 29 of Set 2 | santiago del estero
# Processing Record 30 of Set 2 | dudinka
# Processing Record 31 of Set 2 | sitka
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 34 of Set 2 | flinders
# Processing Record 35 of Set 2 | saint anthony
# Processing Record 36 of Set 2 | khatanga
# Processing Record 37 of Set 2 | cairns
# Processing Record 38 of Set 2 | barrow
# Processing Record 39 of Set 2 | raudeberg
# Processing Record 40 of Set 2 | mahebourg
# Processing Record 41 of Set 2 | burnie
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | constitucion
# Processing Record 44 of Set 2 | marshfield
# Processing Record 45 of Set 2 | tuktoyaktuk
# Processing Record 46 of Set 2 | coquimbo
# Processing Record 47 of Set 2 | yugorsk
# Processing Record 48 of Set 2 | laguna
# Processing Record 49 of Set 2 | nauta
# Processing Record 50 of Set 2 | hilo
# Processing Record 1 of Set 3 | ribeira grande
# Processing Record 2 of Set 3 | lahaina
# Processing Record 3 of Set 3 | arcachon
# Processing Record 4 of Set 3 | puerto gaitan
# Processing Record 5 of Set 3 | salta
# Processing Record 6 of Set 3 | ancud
# Processing Record 7 of Set 3 | severo-kurilsk
# Processing Record 8 of Set 3 | georgetown
# Processing Record 9 of Set 3 | homer
# Processing Record 10 of Set 3 | zarubino
# Processing Record 11 of Set 3 | chuy
# Processing Record 12 of Set 3 | college
# Processing Record 13 of Set 3 | dumai
# Processing Record 14 of Set 3 | portland
# Processing Record 15 of Set 3 | langres
# Processing Record 16 of Set 3 | bambanglipuro
# Processing Record 17 of Set 3 | acapulco
# Processing Record 18 of Set 3 | at-bashi
# Processing Record 19 of Set 3 | saint-philippe
# Processing Record 20 of Set 3 | saint-augustin
# Processing Record 21 of Set 3 | santa maria
# Processing Record 22 of Set 3 | kodiak
# Processing Record 23 of Set 3 | aykhal
# Processing Record 24 of Set 3 | leningradskiy
# Processing Record 25 of Set 3 | ondorhaan
# City not found. Skipping...
# Processing Record 26 of Set 3 | ayna
# Processing Record 27 of Set 3 | hit
# Processing Record 28 of Set 3 | bom jesus
# Processing Record 29 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 30 of Set 3 | pacific grove
# Processing Record 31 of Set 3 | ugoofaaru
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | faanui
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | los llanos de aridane
# Processing Record 36 of Set 3 | henties bay
# Processing Record 37 of Set 3 | swellendam
# Processing Record 38 of Set 3 | synya
# Processing Record 39 of Set 3 | itoman
# Processing Record 40 of Set 3 | cabatuan
# Processing Record 41 of Set 3 | soyo
# Processing Record 42 of Set 3 | bluff
# Processing Record 43 of Set 3 | vostochnyy
# Processing Record 44 of Set 3 | tasiilaq
# Processing Record 45 of Set 3 | port alfred
# Processing Record 46 of Set 3 | zabolotovka
# Processing Record 47 of Set 3 | cap malheureux
# Processing Record 48 of Set 3 | caravelas
# Processing Record 49 of Set 3 | jardim
# Processing Record 50 of Set 3 | vila velha
# Processing Record 1 of Set 4 | muros
# Processing Record 2 of Set 4 | lodja
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | atuona
# Processing Record 5 of Set 4 | saskylakh
# Processing Record 6 of Set 4 | esperance
# Processing Record 7 of Set 4 | maracacume
# Processing Record 8 of Set 4 | conde
# Processing Record 9 of Set 4 | bathsheba
# Processing Record 10 of Set 4 | mount gambier
# Processing Record 11 of Set 4 | trincomalee
# Processing Record 12 of Set 4 | montepuez
# Processing Record 13 of Set 4 | agadir
# Processing Record 14 of Set 4 | el dorado
# Processing Record 15 of Set 4 | naze
# Processing Record 16 of Set 4 | takhtamygda
# Processing Record 17 of Set 4 | sangolqui
# Processing Record 18 of Set 4 | ust-tsilma
# Processing Record 19 of Set 4 | yei
# Processing Record 20 of Set 4 | yashkino
# Processing Record 21 of Set 4 | jamestown
# Processing Record 22 of Set 4 | ginda
# Processing Record 23 of Set 4 | baturaja
# Processing Record 24 of Set 4 | bredasdorp
# Processing Record 25 of Set 4 | karratha
# Processing Record 26 of Set 4 | rocha
# Processing Record 27 of Set 4 | arlit
# Processing Record 28 of Set 4 | katsuura
# Processing Record 29 of Set 4 | shingu
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | krasnogvardeyskiy
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | khash
# Processing Record 34 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 35 of Set 4 | mvomero
# Processing Record 36 of Set 4 | port keats
# Processing Record 37 of Set 4 | shizunai
# Processing Record 38 of Set 4 | horni briza
# Processing Record 39 of Set 4 | kaitangata
# Processing Record 40 of Set 4 | fukue
# Processing Record 41 of Set 4 | port blair
# Processing Record 42 of Set 4 | yellowknife
# Processing Record 43 of Set 4 | yatou
# Processing Record 44 of Set 4 | santa cruz
# Processing Record 45 of Set 4 | springfield
# Processing Record 46 of Set 4 | khotyn
# Processing Record 47 of Set 4 | east london
# Processing Record 48 of Set 4 | erenhot
# Processing Record 49 of Set 4 | mersing
# Processing Record 50 of Set 4 | kuala terengganu
# Processing Record 1 of Set 5 | upernavik
# Processing Record 2 of Set 5 | lorengau
# Processing Record 3 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 5 | stratford-upon-avon
# Processing Record 5 of Set 5 | beringovskiy
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | boralday
# Processing Record 8 of Set 5 | ambilobe
# Processing Record 9 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 5 | eregli
# Processing Record 11 of Set 5 | tiznit
# Processing Record 12 of Set 5 | hasaki
# Processing Record 13 of Set 5 | grindavik
# Processing Record 14 of Set 5 | koumac
# Processing Record 15 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 5 | colquechaca
# Processing Record 17 of Set 5 | loandjili
# Processing Record 18 of Set 5 | ongandjera
# Processing Record 19 of Set 5 | petropavl
# Processing Record 20 of Set 5 | hibbing
# Processing Record 21 of Set 5 | vao
# Processing Record 22 of Set 5 | the valley
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 25 of Set 5 | sitio novo do tocantins
# Processing Record 26 of Set 5 | alenquer
# Processing Record 27 of Set 5 | antofagasta
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | santo tomas
# Processing Record 30 of Set 5 | ksenyevka
# City not found. Skipping...
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | katobu
# Processing Record 33 of Set 5 | vitimskiy
# City not found. Skipping...
# Processing Record 34 of Set 5 | mayo
# Processing Record 35 of Set 5 | ust-kuyga
# Processing Record 36 of Set 5 | araouane
# Processing Record 37 of Set 5 | longyearbyen
# Processing Record 38 of Set 5 | liberal
# Processing Record 39 of Set 5 | san policarpo
# Processing Record 40 of Set 5 | shubarshi
# Processing Record 41 of Set 5 | manokwari
# Processing Record 42 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 5 | xining
# Processing Record 44 of Set 5 | honolulu
# Processing Record 45 of Set 5 | baracoa
# Processing Record 46 of Set 5 | lovozero
# Processing Record 47 of Set 5 | mana
# Processing Record 48 of Set 5 | mount isa
# Processing Record 49 of Set 5 | port lincoln
# Processing Record 50 of Set 5 | mareeba
# Processing Record 1 of Set 6 | lianzhou
# Processing Record 2 of Set 6 | dunedin
# Processing Record 3 of Set 6 | manaure
# Processing Record 4 of Set 6 | cumberland
# Processing Record 5 of Set 6 | rungata
# City not found. Skipping...
# Processing Record 6 of Set 6 | ulaangom
# Processing Record 7 of Set 6 | sawtell
# Processing Record 8 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 9 of Set 6 | maine-soroa
# Processing Record 10 of Set 6 | sorland
# Processing Record 11 of Set 6 | high level
# Processing Record 12 of Set 6 | sorata
# Processing Record 13 of Set 6 | puerto baquerizo moreno
# Processing Record 14 of Set 6 | shakawe
# Processing Record 15 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 6 | kachug
# Processing Record 17 of Set 6 | togur
# Processing Record 18 of Set 6 | talcahuano
# Processing Record 19 of Set 6 | elko
# Processing Record 20 of Set 6 | qaqortoq
# Processing Record 21 of Set 6 | migori
# Processing Record 22 of Set 6 | southbridge
# Processing Record 23 of Set 6 | bud
# Processing Record 24 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 6 | anantapur
# Processing Record 26 of Set 6 | luchegorsk
# Processing Record 27 of Set 6 | itaituba
# Processing Record 28 of Set 6 | el sauzal
# Processing Record 29 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 6 | bambous virieux
# Processing Record 31 of Set 6 | sharjah
# Processing Record 32 of Set 6 | blois
# Processing Record 33 of Set 6 | visby
# Processing Record 34 of Set 6 | kokopo
# Processing Record 35 of Set 6 | seoul
# Processing Record 36 of Set 6 | uyuni
# Processing Record 37 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 6 | nyurba
# Processing Record 39 of Set 6 | celestun
# Processing Record 40 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 41 of Set 6 | torata
# Processing Record 42 of Set 6 | goes
# Processing Record 43 of Set 6 | morro bay
# Processing Record 44 of Set 6 | presque isle
# Processing Record 45 of Set 6 | ambon
# Processing Record 46 of Set 6 | clifton
# Processing Record 47 of Set 6 | nacala
# Processing Record 48 of Set 6 | shagamu
# Processing Record 49 of Set 6 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 50 of Set 6 | berlevag
# Processing Record 1 of Set 7 | port hardy
# Processing Record 2 of Set 7 | porecatu
# Processing Record 3 of Set 7 | fort william
# Processing Record 4 of Set 7 | salalah
# Processing Record 5 of Set 7 | luena
# Processing Record 6 of Set 7 | fairbanks
# Processing Record 7 of Set 7 | batemans bay
# Processing Record 8 of Set 7 | acajutla
# Processing Record 9 of Set 7 | mosquera
# Processing Record 10 of Set 7 | karwar
# Processing Record 11 of Set 7 | riosucio
# Processing Record 12 of Set 7 | lerwick
# Processing Record 13 of Set 7 | khandbari
# Processing Record 14 of Set 7 | bengkulu
# Processing Record 15 of Set 7 | souillac
# Processing Record 16 of Set 7 | broome
# Processing Record 17 of Set 7 | villa del rosario
# Processing Record 18 of Set 7 | qaanaaq
# Processing Record 19 of Set 7 | chumphon
# Processing Record 20 of Set 7 | pangnirtung
# Processing Record 21 of Set 7 | wanning
# Processing Record 22 of Set 7 | borovskoy
# Processing Record 23 of Set 7 | gouyave
# Processing Record 24 of Set 7 | koslan
# Processing Record 25 of Set 7 | baykit
# Processing Record 26 of Set 7 | along
# Processing Record 27 of Set 7 | alofi
# Processing Record 28 of Set 7 | nawa
# Processing Record 29 of Set 7 | muravlenko
# Processing Record 30 of Set 7 | ilesha
# Processing Record 31 of Set 7 | rio gallegos
# Processing Record 32 of Set 7 | luanda
# Processing Record 33 of Set 7 | clyde river
# Processing Record 34 of Set 7 | chilca
# Processing Record 35 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 36 of Set 7 | iqaluit
# Processing Record 37 of Set 7 | caraguatay
# Processing Record 38 of Set 7 | bethel
# Processing Record 39 of Set 7 | cayenne
# Processing Record 40 of Set 7 | aripuana
# Processing Record 41 of Set 7 | astoria
# Processing Record 42 of Set 7 | idukki
# Processing Record 43 of Set 7 | cidreira
# Processing Record 44 of Set 7 | marsala
# Processing Record 45 of Set 7 | hobyo
# Processing Record 46 of Set 7 | aleksandrovskoye
# Processing Record 47 of Set 7 | nelson bay
# Processing Record 48 of Set 7 | la ronge
# Processing Record 49 of Set 7 | hovd
# Processing Record 50 of Set 7 | hami
# Processing Record 1 of Set 8 | poum
# Processing Record 2 of Set 8 | bartica
# Processing Record 3 of Set 8 | luderitz
# Processing Record 4 of Set 8 | stonewall
# Processing Record 5 of Set 8 | labuhan
# Processing Record 6 of Set 8 | kyabe
# Processing Record 7 of Set 8 | terme
# Processing Record 8 of Set 8 | coahuayana
# Processing Record 9 of Set 8 | kibre mengist
# Processing Record 10 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 8 | moron
# Processing Record 12 of Set 8 | north bend
# Processing Record 13 of Set 8 | warrnambool
# Processing Record 14 of Set 8 | husavik
# Processing Record 15 of Set 8 | pakruojis
# Processing Record 16 of Set 8 | coihaique
# Processing Record 17 of Set 8 | belaya gora
# Processing Record 18 of Set 8 | porto walter
# Processing Record 19 of Set 8 | blagoyevo
# Processing Record 20 of Set 8 | kamina
# Processing Record 21 of Set 8 | starokozache
# Processing Record 22 of Set 8 | cockburn town
# Processing Record 23 of Set 8 | kerema
# Processing Record 24 of Set 8 | chokwe
# Processing Record 25 of Set 8 | saint-ambroise
# Processing Record 26 of Set 8 | tutin
# Processing Record 27 of Set 8 | pevek
# Processing Record 28 of Set 8 | anahuac
# Processing Record 29 of Set 8 | sandpoint
# Processing Record 30 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 8 | nanakuli
# Processing Record 32 of Set 8 | zhigansk
# Processing Record 33 of Set 8 | belyy yar
# Processing Record 34 of Set 8 | isangel
# Processing Record 35 of Set 8 | feodosiya
# Processing Record 36 of Set 8 | amarante
# Processing Record 37 of Set 8 | puerto escondido
# Processing Record 38 of Set 8 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 8 | chachapoyas
# Processing Record 40 of Set 8 | abrego
# Processing Record 41 of Set 8 | sobolevo
# Processing Record 42 of Set 8 | lagoa
# Processing Record 43 of Set 8 | poronaysk
# Processing Record 44 of Set 8 | kiruna
# Processing Record 45 of Set 8 | kabanjahe
# Processing Record 46 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 47 of Set 8 | lakes entrance
# Processing Record 48 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 49 of Set 8 | talara
# Processing Record 50 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 9 | chitungwiza
# Processing Record 2 of Set 9 | adrar
# Processing Record 3 of Set 9 | ixtapa
# Processing Record 4 of Set 9 | mehamn
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | moroto
# Processing Record 7 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 8 of Set 9 | kavieng
# Processing Record 9 of Set 9 | deputatskiy
# Processing Record 10 of Set 9 | bodden town
# Processing Record 11 of Set 9 | castanos
# Processing Record 12 of Set 9 | were ilu
# Processing Record 13 of Set 9 | yar-sale
# Processing Record 14 of Set 9 | andijon
# Processing Record 15 of Set 9 | baoshan
# Processing Record 16 of Set 9 | hualmay
# Processing Record 17 of Set 9 | ahipara
# Processing Record 18 of Set 9 | kununurra
# Processing Record 19 of Set 9 | kaeo
# Processing Record 20 of Set 9 | ciudad bolivar
# Processing Record 21 of Set 9 | juba
# Processing Record 22 of Set 9 | bestobe
# Processing Record 23 of Set 9 | lata
# Processing Record 24 of Set 9 | jadu
# Processing Record 25 of Set 9 | pearl
# Processing Record 26 of Set 9 | opuwo
# Processing Record 27 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 9 | porosozero
# Processing Record 29 of Set 9 | olafsvik
# Processing Record 30 of Set 9 | beloha
# Processing Record 31 of Set 9 | yangjiang
# Processing Record 32 of Set 9 | carnarvon
# Processing Record 33 of Set 9 | santa ines
# Processing Record 34 of Set 9 | panalingaan
# Processing Record 35 of Set 9 | tessalit
# Processing Record 36 of Set 9 | tazovskiy
# Processing Record 37 of Set 9 | klin
# Processing Record 38 of Set 9 | tsabong
# Processing Record 39 of Set 9 | miguel calmon
# Processing Record 40 of Set 9 | floresta
# Processing Record 41 of Set 9 | axim
# Processing Record 42 of Set 9 | kamennogorsk
# Processing Record 43 of Set 9 | tabou
# Processing Record 44 of Set 9 | te anau
# Processing Record 45 of Set 9 | turayf
# Processing Record 46 of Set 9 | choa saidan shah
# Processing Record 47 of Set 9 | muncar
# Processing Record 48 of Set 9 | calabozo
# Processing Record 49 of Set 9 | chimbote
# Processing Record 50 of Set 9 | tabas
# Processing Record 1 of Set 10 | alamos
# Processing Record 2 of Set 10 | komsomolskiy
# Processing Record 3 of Set 10 | vostok
# Processing Record 4 of Set 10 | santa vitoria do palmar
# Processing Record 5 of Set 10 | garden city
# Processing Record 6 of Set 10 | winnemucca
# Processing Record 7 of Set 10 | ilebo
# Processing Record 8 of Set 10 | hede
# Processing Record 9 of Set 10 | margate
# Processing Record 10 of Set 10 | miraflores
# Processing Record 11 of Set 10 | ulladulla
# Processing Record 12 of Set 10 | armidale
# Processing Record 13 of Set 10 | gazimurskiy zavod
# Processing Record 14 of Set 10 | bandraboua
# Processing Record 15 of Set 10 | pitimbu
# Processing Record 16 of Set 10 | acarau
# Processing Record 17 of Set 10 | srednekolymsk
# Processing Record 18 of Set 10 | vila do maio
# Processing Record 19 of Set 10 | simpang
# Processing Record 20 of Set 10 | fortuna
# Processing Record 21 of Set 10 | sao filipe
# Processing Record 22 of Set 10 | valkeakoski
# Processing Record 23 of Set 10 | galle
# Processing Record 24 of Set 10 | bonfim
# Processing Record 25 of Set 10 | jammalamadugu
# Processing Record 26 of Set 10 | harlingen
# Processing Record 27 of Set 10 | harmanli
# Processing Record 28 of Set 10 | la rioja
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | vila franca do campo
# Processing Record 31 of Set 10 | suileng
# Processing Record 32 of Set 10 | ormara
# Processing Record 33 of Set 10 | faridkot
# Processing Record 34 of Set 10 | almeirim
# Processing Record 35 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 36 of Set 10 | kaputa
# Processing Record 37 of Set 10 | samarai
# Processing Record 38 of Set 10 | hayden
# Processing Record 39 of Set 10 | biertan
# Processing Record 40 of Set 10 | aklavik
# Processing Record 41 of Set 10 | umm kaddadah
# Processing Record 42 of Set 10 | pangody
# Processing Record 43 of Set 10 | kirakira
# Processing Record 44 of Set 10 | kielce
# Processing Record 45 of Set 10 | vadso
# Processing Record 46 of Set 10 | takoradi
# Processing Record 47 of Set 10 | mahuva
# Processing Record 48 of Set 10 | pisco
# Processing Record 49 of Set 10 | kenai
# Processing Record 50 of Set 10 | le port
# Processing Record 1 of Set 11 | necochea
# Processing Record 2 of Set 11 | ambulu
# Processing Record 3 of Set 11 | buriti
# Processing Record 4 of Set 11 | solnechnyy
# Processing Record 5 of Set 11 | talnakh
# Processing Record 6 of Set 11 | ostrovnoy
# Processing Record 7 of Set 11 | general pico
# Processing Record 8 of Set 11 | oranjemund
# Processing Record 9 of Set 11 | mitu
# Processing Record 10 of Set 11 | sioux lookout
# Processing Record 11 of Set 11 | kudahuvadhoo
# Processing Record 12 of Set 11 | muscat
# Processing Record 13 of Set 11 | selcuk
# Processing Record 14 of Set 11 | leon
# Processing Record 15 of Set 11 | huntsville
# Processing Record 16 of Set 11 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 17 of Set 11 | rapid valley
# Processing Record 18 of Set 11 | bonthe
# Processing Record 19 of Set 11 | saldanha
# Processing Record 20 of Set 11 | gangotri
# City not found. Skipping...
# Processing Record 21 of Set 11 | erzin
# Processing Record 22 of Set 11 | ocampo
# Processing Record 23 of Set 11 | alyangula
# Processing Record 24 of Set 11 | kendari
# Processing Record 25 of Set 11 | fomboni
# Processing Record 26 of Set 11 | jesi
# Processing Record 27 of Set 11 | pak chong
# Processing Record 28 of Set 11 | meulaboh
# Processing Record 29 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 11 | anchorage
# Processing Record 31 of Set 11 | parkersburg
# Processing Record 32 of Set 11 | shellbrook
# Processing Record 33 of Set 11 | sambava
# Processing Record 34 of Set 11 | viedma
# Processing Record 35 of Set 11 | sandnessjoen
# Processing Record 36 of Set 11 | oranjestad
# Processing Record 37 of Set 11 | kangaatsiaq
# Processing Record 38 of Set 11 | bumba
# Processing Record 39 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 11 | iracoubo
# Processing Record 41 of Set 11 | deniliquin
# Processing Record 42 of Set 11 | quelimane
# Processing Record 43 of Set 11 | dakar
# Processing Record 44 of Set 11 | codrington
# Processing Record 45 of Set 11 | cavalcante
# Processing Record 46 of Set 11 | mabaruma
# Processing Record 47 of Set 11 | santa rosa
# Processing Record 48 of Set 11 | kerki
# City not found. Skipping...
# Processing Record 49 of Set 11 | inta
# Processing Record 50 of Set 11 | jutai
# Processing Record 1 of Set 12 | yamada
# Processing Record 2 of Set 12 | nsanje
# Processing Record 3 of Set 12 | paamiut
# Processing Record 4 of Set 12 | stanislav
# Processing Record 5 of Set 12 | manhumirim
# Processing Record 6 of Set 12 | merta
# Processing Record 7 of Set 12 | lipari
# Processing Record 8 of Set 12 | port hedland
# Processing Record 9 of Set 12 | rudsar
# Processing Record 10 of Set 12 | ankang
# Processing Record 11 of Set 12 | luganville
# Processing Record 12 of Set 12 | junagarh
# Processing Record 13 of Set 12 | kamaishi
# Processing Record 14 of Set 12 | vatne
# Processing Record 15 of Set 12 | tarnos
# Processing Record 16 of Set 12 | shahr-e babak
# Processing Record 17 of Set 12 | pajan
# Processing Record 18 of Set 12 | manicore
# Processing Record 19 of Set 12 | saint-marc-des-carrieres
# Processing Record 20 of Set 12 | aswan
# Processing Record 21 of Set 12 | derzhavinsk
# Processing Record 22 of Set 12 | bagdarin
# Processing Record 23 of Set 12 | badaojiang
# City not found. Skipping...
# Processing Record 24 of Set 12 | brae
# Processing Record 25 of Set 12 | palmer
# Processing Record 26 of Set 12 | floro
# Processing Record 27 of Set 12 | polunochnoye
# Processing Record 28 of Set 12 | dijkot
# Processing Record 29 of Set 12 | lebu
# Processing Record 30 of Set 12 | elizabeth city
# Processing Record 31 of Set 12 | nuevo progreso
# Processing Record 32 of Set 12 | benjamin hill
# Processing Record 33 of Set 12 | victor harbor
# Processing Record 34 of Set 12 | saint-gabriel
# Processing Record 35 of Set 12 | yanam
# Processing Record 36 of Set 12 | yulara
# Processing Record 37 of Set 12 | shima
# Processing Record 38 of Set 12 | trairi
# Processing Record 39 of Set 12 | mogadishu
# Processing Record 40 of Set 12 | saint-francois
# Processing Record 41 of Set 12 | taitung
# Processing Record 42 of Set 12 | mezen
# Processing Record 43 of Set 12 | oktyabrskiy
# Processing Record 44 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 12 | neustadt
# Processing Record 46 of Set 12 | manzanillo
# Processing Record 47 of Set 12 | zabid
# Processing Record 48 of Set 12 | bosaso
# Processing Record 49 of Set 12 | fairhope
# Processing Record 50 of Set 12 | melfi
# Processing Record 1 of Set 13 | arnprior
# Processing Record 2 of Set 13 | labytnangi
# Processing Record 3 of Set 13 | jabinyanah
# Processing Record 4 of Set 13 | atar
# Processing Record 5 of Set 13 | veseloyarsk
# Processing Record 6 of Set 13 | artyom
# Processing Record 7 of Set 13 | yankton
# Processing Record 8 of Set 13 | rupert
# Processing Record 9 of Set 13 | vallenar
# Processing Record 10 of Set 13 | pitkyaranta
# Processing Record 11 of Set 13 | micheweni
# Processing Record 12 of Set 13 | polovinnoye
# Processing Record 13 of Set 13 | gravdal
# Processing Record 14 of Set 13 | kholm
# Processing Record 15 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 13 | maloshuyka
# City not found. Skipping...
# Processing Record 17 of Set 13 | mountain home
# Processing Record 18 of Set 13 | kloulklubed
# Processing Record 19 of Set 13 | shimoda
# Processing Record 20 of Set 13 | pathein
# Processing Record 21 of Set 13 | smithers
# Processing Record 22 of Set 13 | ternate
# Processing Record 23 of Set 13 | chivilcoy
# Processing Record 24 of Set 13 | tefe
# Processing Record 25 of Set 13 | nokha
# Processing Record 26 of Set 13 | el badari
# City not found. Skipping...
# Processing Record 27 of Set 13 | lompoc
# Processing Record 28 of Set 13 | khetri
# Processing Record 29 of Set 13 | piacabucu
# Processing Record 30 of Set 13 | mandalgovi
# Processing Record 31 of Set 13 | madras
# Processing Record 32 of Set 13 | souris
# Processing Record 33 of Set 13 | hollins
# Processing Record 34 of Set 13 | emet
# Processing Record 35 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 13 | amga
# Processing Record 37 of Set 13 | helong
# Processing Record 38 of Set 13 | general roca
# Processing Record 39 of Set 13 | san miguel
# Processing Record 40 of Set 13 | manggar
# Processing Record 41 of Set 13 | asfi
# Processing Record 42 of Set 13 | roald
# Processing Record 43 of Set 13 | torbay
# Processing Record 44 of Set 13 | tandil
# Processing Record 45 of Set 13 | yavas
# Processing Record 46 of Set 13 | moose factory
# Processing Record 47 of Set 13 | orange cove
# Processing Record 48 of Set 13 | atchison
# Processing Record 49 of Set 13 | pushkino
# Processing Record 50 of Set 13 | butzow
# Processing Record 1 of Set 14 | kahului
# Processing Record 2 of Set 14 | priiskovyy
# Processing Record 3 of Set 14 | saint-joseph
# Processing Record 4 of Set 14 | gamba
# Processing Record 5 of Set 14 | darhan
# Processing Record 6 of Set 14 | rogovatoye
# Processing Record 7 of Set 14 | xai-xai
# Processing Record 8 of Set 14 | tuatapere
# Processing Record 9 of Set 14 | kambove
# Processing Record 10 of Set 14 | monterey
# Processing Record 11 of Set 14 | tuburan
# Processing Record 12 of Set 14 | miramar
# Processing Record 13 of Set 14 | lowestoft
# Processing Record 14 of Set 14 | strezhevoy
# Processing Record 15 of Set 14 | pangai
# Processing Record 16 of Set 14 | mahajanga
# Processing Record 17 of Set 14 | jaguaribe
# Processing Record 18 of Set 14 | port hawkesbury
# Processing Record 19 of Set 14 | north platte
# Processing Record 20 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 14 | nemuro
# Processing Record 22 of Set 14 | nador
# Processing Record 23 of Set 14 | birjand
# Processing Record 24 of Set 14 | blacksburg
# Processing Record 25 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 26 of Set 14 | gull lake
# Processing Record 27 of Set 14 | kaoma
# Processing Record 28 of Set 14 | srandakan
# Processing Record 29 of Set 14 | weleri
# Processing Record 30 of Set 14 | ovruch
# Processing Record 31 of Set 14 | pitiquito
# Processing Record 32 of Set 14 | balikpapan
# Processing Record 33 of Set 14 | katherine
# Processing Record 34 of Set 14 | avanigadda
# Processing Record 35 of Set 14 | chanthaburi
# Processing Record 36 of Set 14 | plastun
# Processing Record 37 of Set 14 | bitung
# Processing Record 38 of Set 14 | bourail
# Processing Record 39 of Set 14 | emba
# Processing Record 40 of Set 14 | kyshtovka
# Processing Record 41 of Set 14 | aksu
# Processing Record 42 of Set 14 | port augusta
# Processing Record 43 of Set 14 | enterprise
# Processing Record 44 of Set 14 | campos belos
# Processing Record 45 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 46 of Set 14 | krasnaya zarya
# Processing Record 47 of Set 14 | rio grande
# Processing Record 48 of Set 14 | ponta delgada
# Processing Record 49 of Set 14 | kieta
# Processing Record 50 of Set 14 | olinda
# Processing Record 1 of Set 15 | doha
# Processing Record 2 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 3 of Set 15 | kyzyl-suu
# Processing Record 4 of Set 15 | teguldet
# Processing Record 5 of Set 15 | gazojak
# Processing Record 6 of Set 15 | baruun-urt
# Processing Record 7 of Set 15 | havelock
# Processing Record 8 of Set 15 | yumen
# Processing Record 9 of Set 15 | lixourion
# Processing Record 10 of Set 15 | falealupo
# City not found. Skipping...
# Processing Record 11 of Set 15 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 15 | shasta lake
# Processing Record 13 of Set 15 | bandarbeyla
# Processing Record 14 of Set 15 | taoudenni
# Processing Record 15 of Set 15 | amapa
# Processing Record 16 of Set 15 | yaan
# Processing Record 17 of Set 15 | bangassou
# Processing Record 18 of Set 15 | hope
# Processing Record 19 of Set 15 | esperantinopolis
# Processing Record 20 of Set 15 | newark
# Processing Record 21 of Set 15 | ayagoz
# Processing Record 22 of Set 15 | eenhana
# Processing Record 23 of Set 15 | oussouye
# Processing Record 24 of Set 15 | sibolga
# Processing Record 25 of Set 15 | walvis bay
# Processing Record 26 of Set 15 | mizdah
# Processing Record 27 of Set 15 | farafangana
# Processing Record 28 of Set 15 | la asuncion
# Processing Record 29 of Set 15 | vestmannaeyjar
# Processing Record 30 of Set 15 | emporia
# Processing Record 31 of Set 15 | forestville
# Processing Record 32 of Set 15 | kallaste
# Processing Record 33 of Set 15 | fayaoue
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Recall that we can convert a list of dictionaries to a pandas dataframe using df =pd.Dataframe (list with dictionaries)
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Kavaratti  10.5669   72.6420     81.27        77          61
# 1         Cherskiy  68.7500  161.3000     58.28        77         100
# 2        Cape Town -33.9258   18.4232     53.11        86           0
# 3     Saint George  37.1041 -113.5841     82.99        52           0
# 4     Ornskoldsvik  63.2909   18.7153     54.55       100           0
# 5          Rikitea -23.1203 -134.9692     68.07        76         100
# 6           Matata -37.8833  176.7500     61.95        90          72
# 7  Arraial Do Cabo -22.9661  -42.0278     65.28        70          82
# 8          Waipawa -41.4122  175.5153     52.05        90          96
# 9          Chapais  49.7834  -74.8492     60.58        90           0
#
#    Wind Speed Country current Description
# 0       17.96      IN       broken clouds
# 1       10.07      RU          light rain
# 2        3.44      ZA           clear sky
# 3        4.61      US           clear sky
# 4        4.61      SE           clear sky
# 5       14.85      PF          light rain
# 6        5.59      NZ       broken clouds
# 7        9.75      BR       broken clouds
# 8        4.21      NZ          light rain
# 9        2.68      CA           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
